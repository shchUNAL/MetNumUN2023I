# %% [markdown]
# <a href="https://colab.research.google.com/github/shchUNAL/MetNumUN2023I/blob/main/Lab3/shernandezchcognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![IBM PY0101EN Certificate _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Validación: https://courses.cognitiveclass.ai/certificates/3c380b3071d34bf0991748a8a542dd68

# %% [markdown]
# ![IBM DA0101EN Certificate _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Validación: https://courses.cognitiveclass.ai/certificates/6abb4be26b5541cfad42cf7f9a63f6ee

# %% [markdown]
# ![IBM DV0101EN Certificate _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Validación: https://courses.cognitiveclass.ai/certificates/66ab3c0eb8e0413897d0abe6d2a144de

# %% [markdown]
# LinkedIn: https://www.linkedin.com/in/santiago-hernandez-chaparro-2074a0222

# %% [markdown]
# ![LinkedIn.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![LinkedIn1.jpg](data:image/jpeg;base64,...)
